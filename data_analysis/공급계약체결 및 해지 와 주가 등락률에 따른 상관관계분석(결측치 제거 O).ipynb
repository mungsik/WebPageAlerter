# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 주가 등락률 데이터 로등해서 df_sct, df_scc 에 담기
df_scc = pd.read_csv("datas/scc_fluctuation.csv", encoding="cp949")
df_scc.shape
# Out:
# (4160, 4)

# %%
df_scc.columns =["fluctuation", "ticker", "reception_date", "registration_date"]
df_scc.head()
# Out:
#    fluctuation  ticker reception_date registration_date
# 0        29.60  264660     2019-08-20        2019-08-20
# 1         1.50  241790     2019-08-20        2019-08-20
# 2         0.00   17940     2019-08-21        2019-08-21
# 3         3.78  143540     2019-08-21        2019-08-21
# 4         0.37    9440     2019-08-22        2019-08-22

# %%
modify_data = df_scc.drop(['reception_date', 'registration_date', 'ticker'], axis= 'columns')

# %%
modify_data
# Out:
#       fluctuation
# 0           29.60
# 46          21.14
# 279         23.96
# 447         23.11
# 450         20.98
# 600         29.90
# 601         23.78
# 662         29.95
# 663         29.95
# 949         24.25
# 964         25.12
# 981         23.82
# 982         23.82
# 1023        29.85
# 1063        24.59
# 1124        29.89
# 1138        29.91
# 1198        29.51
# 1358        29.88
# 1482        25.44
# 2611        25.51
# 2944        29.88
# 3196        21.69
# 3272        29.89
# 3448        29.82
# 3458        29.90
# 4088        22.48

# %%
df
# Out:
#      fluctuation
# 0          29.60
# 46         21.14
# 279        23.96
# 447        23.11
# 450        20.98

# %%
df_scc
# Out:
#       fluctuation  ticker reception_date registration_date
# 0           29.60  264660     2019-08-20        2019-08-20
# 1            1.50  241790     2019-08-20        2019-08-20
# 2            0.00   17940     2019-08-21        2019-08-21
# 3            3.78  143540     2019-08-21        2019-08-21
# 4            0.37    9440     2019-08-22        2019-08-22
# ...           ...     ...            ...               ...
# 4155        -1.62   78000     2022-08-18        2022-08-18
# 4156         0.00   32860     2022-08-18        2022-08-18
# 4157        -0.68  100090     2022-08-19        2022-08-19
# 4158        -0.49   68270     2022-08-19        2022-08-19
# 4159         1.22   86980     2022-08-19        2022-08-19
#
# [4160 rows x 4 columns]

# %%
df_scc.columns =["fluctuation", "ticker", "reception_date", "registration_date"]
df_scc.head()
# Out:
#    fluctuation  ticker reception_date registration_date
# 0        29.60  264660     2019-08-20        2019-08-20
# 1         1.50  241790     2019-08-20        2019-08-20
# 2         0.00   17940     2019-08-21        2019-08-21
# 3         3.78  143540     2019-08-21        2019-08-21
# 4         0.37    9440     2019-08-22        2019-08-22

# %%
modify_data = df_scc.drop(['reception_date', 'registration_date', 'ticker'], axis= 'columns')

# %%
modify_data
# Out:
#       fluctuation
# 0           29.60
# 1            1.50
# 2            0.00
# 3            3.78
# 4            0.37
# ...           ...
# 4155        -1.62
# 4156         0.00
# 4157        -0.68
# 4158        -0.49
# 4159         1.22
#
# [4160 rows x 1 columns]

# %%
drop_index = modify_data[modify_data['fluctuation'] >= 20 ].index

# %%
drop_index
# Out:
# Int64Index([   0,   46,  279,  447,  450,  600,  601,  662,  663,  949,  964,
#              981,  982, 1023, 1063, 1124, 1138, 1198, 1358, 1482, 2611, 2944,
#             3196, 3272, 3448, 3458, 4088],
#            dtype='int64')

# %%
modify_data
# Out:
#       fluctuation
# 0           29.60
# 1            1.50
# 2            0.00
# 3            3.78
# 4            0.37
# ...           ...
# 4155        -1.62
# 4156         0.00
# 4157        -0.68
# 4158        -0.49
# 4159         1.22
#
# [4160 rows x 1 columns]

# %%
df = modify_data.drop(drop_index)
df
# Out:
#       fluctuation
# 1            1.50
# 2            0.00
# 3            3.78
# 4            0.37
# 5           -0.78
# ...           ...
# 4155        -1.62
# 4156         0.00
# 4157        -0.68
# 4158        -0.49
# 4159         1.22
#
# [4133 rows x 1 columns]

# %%
drop_index = df[df['fluctuation'] <= -20 ].index

# %%
drop_index
# Out:
# Int64Index([545, 546], dtype='int64')

# %%
drop_missing_value = df.drop(drop_index)
drop_missing_value
# Out:
#       fluctuation
# 1            1.50
# 2            0.00
# 3            3.78
# 4            0.37
# 5           -0.78
# ...           ...
# 4155        -1.62
# 4156         0.00
# 4157        -0.68
# 4158        -0.49
# 4159         1.22
#
# [4131 rows x 1 columns]

# %%
drop_missing_value.describe()
# Out:
#        fluctuation
# count  4131.000000
# mean      0.705841
# std       3.435309
# min     -17.810000
# 25%      -0.970000
# 50%       0.430000
# 75%       2.265000
# max      18.550000

# %%
drop_missing_value.hist()
# Out:
# array([[<AxesSubplot:title={'center':'fluctuation'}>]], dtype=object)

# %%
plt.hist(drop_missing_value,bins= 50, edgecolor='black')
# Out:
# (array([  2.,   0.,   0.,   1.,   3.,   1.,   2.,   1.,   5.,   2.,   3.,
#           8.,  11.,  11.,  22.,  26.,  32.,  49.,  94.,  90., 137., 207.,
#         274., 401., 649., 467., 421., 299., 212., 170., 122.,  90.,  73.,
#          87.,  30.,  20.,  22.,  18.,  15.,   9.,  11.,   8.,   3.,   4.,
#           6.,   4.,   4.,   3.,   0.,   2.]),
#  array([-17.81  , -17.0828, -16.3556, -15.6284, -14.9012, -14.174 ,
#         -13.4468, -12.7196, -11.9924, -11.2652, -10.538 ,  -9.8108,
#          -9.0836,  -8.3564,  -7.6292,  -6.902 ,  -6.1748,  -5.4476,
#          -4.7204,  -3.9932,  -3.266 ,  -2.5388,  -1.8116,  -1.0844,
#          -0.3572,   0.37  ,   1.0972,   1.8244,   2.5516,   3.2788,
#           4.006 ,   4.7332,   5.4604,   6.1876,   6.9148,   7.642 ,
#           8.3692,   9.0964,   9.8236,  10.5508,  11.278 ,  12.0052,
#          12.7324,  13.4596,  14.1868,  14.914 ,  15.6412,  16.3684,
#          17.0956,  17.8228,  18.55  ]),
#  <BarContainer object of 50 artists>)

# %%
drop_missing_value.loc[drop_missing_value['fluctuation'] >= 0].shape[0]
# Out:
# 2580

# %%
drop_missing_value.loc[drop_missing_value['fluctuation'] < 0].shape[0]
# Out:
# 1551

# %%
drop_missing_value.describe()
# Out:
#        fluctuation
# count  4131.000000
# mean      0.705841
# std       3.435309
# min     -17.810000
# 25%      -0.970000
# 50%       0.430000
# 75%       2.265000
# max      18.550000

# %% [markdown]
# 공급계약체결이 있던 날 주가가 -20% 이상 떨어졌거나 20% 이상 증가한 데이터는 삭제했다.
# 즉, -20 < 등락률 < 20 의 데이터를 기준으로 하였다.
#
# ### 그 결과, 62.45 % 의 확률로 주가에 긍정적인 영향을 미친 것을 확인할 수 있었음.
